# %% [markdown]
# # Week 3
#
# ### Normal Distribution Curve Empirical rule
#
# - 68 % of data fall between one standard deviation of mean
# - 95 % of data fall between two standard deviation of mean

# %% [markdown]
# ### Standardizing Data
#
# z score is give by $$ z = (height-mean)/Standard-deviation$$
#
# Mean of standardized data is 0 and standard deviation is 1.

# %% [markdown]
# Normal Approximation is the the method to find the normal area between the range of values for a given normal distubuted data. For this the data needs to be standardized with calculating z score and then the area is found based on computational software. It is used to find the frequencies of data lying between two extreme end points.

# %% [markdown]
# Binomial Probablity is the probablity of getting certain number of successes and failures in an event.
#
# It can be calculated based on the formula given as :
#
# ![image.png](attachment:d7dce276-4a64-4834-b2c0-dac0a70aad46.png)
#
# where n is the number of experiments and k is the number of ways to arrange successes

# %% [markdown]
# Normal Approximation to Binomial Setting is given by first Standardizing the binomial setting and then applying normal approximation.

# %% [markdown]
# ## Quiz section

# %% [markdown]
# Question1: Scores on a certain test follow the normal curve with an average of 1350 and a standard deviation of 120.
#
# What percentage of test takers score below 1230?  (Use the empirical rule.)
#
# ![image.png](attachment:4fd54702-7502-4a22-858f-f6d879a397a3.png)

# %% [markdown]
# Question 2:
# As in the previous question, scores on a certain test follow the normal curve with an average of 1350 and a standard deviation of 120. In order to qualify for a certain job, a candidate needs to score in the top 2.5%. What score does she need?
#
# ![image.png](attachment:b733cb45-304b-411b-8106-75fcf78334d6.png)

# %% [markdown]
# Question 3:
# Recall that the main object in a boxplot is a box that is bounded by the first and the third quartiles. So the length of the box is the difference between the third and the first quartile, which is called the interquartile range. This is a measure of spread of the data; it is sometimes used as an alternative to the standard deviation.
#
# If the data follow the normal curve, then the interquartile range equals how many standard deviations? (You may use the fact that the z-value of the third quartile is 0.7.)
#
# ![image.png](attachment:d83c2a82-a77b-4422-be2e-09df37f129ca.png)

# %% [markdown]
# Question 4:
# A multiple choice exam has 5 questions. Each question has 4 possible answers, of which one is correct. If a student guesses the answers to all five questions, what the chances that he gets 2 correct?
#
# ![image.png](attachment:34ac5ac3-e5c3-4866-ab70-b6a5d9fd84d6.png)

# %% [markdown]
# Question 5:
#
# A fair coin is tossed 6 times. What are the chances of getting 2 tails in each the first 3 and the last 3 tosses?
#
# ![image.png](attachment:b5274320-3898-423a-8abe-7953649e3b5a.png)

# %% [markdown]
# Question 6:
#
# A fair coin is tossed 400 times. Approximately what are the chances to get more than 210 tails?  (Use the empirical rule and the normal approximation to the binomial distribution.)
#
# ![image.png](attachment:7c58ef73-3eff-4486-91bf-b3a8c2122a62.png)
