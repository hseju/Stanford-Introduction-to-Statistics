# %% [markdown]
# # Week 3
#
# ### Normal Distribution Curve Empirical rule
#
# - 68 % of data fall between one standard deviation of mean
# - 95 % of data fall between two standard deviation of mean

# %% [markdown]
# ### Standardizing Data
#
# z score is give by $$ z = (height-mean)/Standard-deviation$$
#
# Mean of standardized data is 0 and standard deviation is 1.

# %% [markdown]
# Normal Approximation is the the method to find the normal area between the range of values for a given normal distubuted data. For this the data needs to be standardized with calculating z score and then the area is found based on computational software. It is used to find the frequencies of data lying between two extreme end points.

# %% [markdown]
# Binomial Probablity is the probablity of getting certain number of successes and failures in an event.
#
# It can be calculated based on the formula given as :
#
# ![image.png](attachment:d7dce276-4a64-4834-b2c0-dac0a70aad46.png)
#
# where n is the number of experiments and k is the number of ways to arrange successes
